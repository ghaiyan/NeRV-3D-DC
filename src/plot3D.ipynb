# %%
#test
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
# 依次获取画布和绘图区并创建 Axes3D 对象
fig = plt.figure()
ax = fig.gca(projection='3d')
dir="/home/ghaiyan/project/NeRV-3D/NeRV/input/"
data="strtad4"
xyz = np.loadtxt(dir+"/"+data+".xyz")
x=xyz[:,0]
y=xyz[:,1]
z=xyz[:,2]
# 绘制3D线性图
ax.plot(x, y, z, color='#C82423')


# 设置标题、轴标签、图例，也可以直接使用 plt.title、plt.xlabel、plt.legend...
ax.set_title('3D View of simulated structure using the '+data +' method', pad=15, fontsize='10')
ax.set_xlabel('x ', color='r', fontsize='14')
ax.set_ylabel('y ', color='g', fontsize='14')
ax.set_zlabel('z ', color='b', fontsize='14')
ax.legend()
plt.axis('off')
plt.savefig(dir+'/{}.pdf'.format(data),pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_21592/3648528046.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#test
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
# 依次获取画布和绘图区并创建 Axes3D 对象
for i in np.around(np.arange(0.1,1,0.1),1):
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    dir="/home/ghaiyan/project/NeRV-3D/IMR90/chr20_5kb"
    data="IMR90-chr20-5kb-"+str(i)
    xyz = np.loadtxt(dir+"/"+data+".xyz")
    x=xyz[:,0]
    y=xyz[:,1]
    z=xyz[:,2]
    # 绘制3D线性图
    ax.plot(x, y, z, color='#C82423')


    # 设置标题、轴标签、图例，也可以直接使用 plt.title、plt.xlabel、plt.legend...
    ax.set_title('3D View of simulated structure using the '+data +' method', pad=15, fontsize='10')
    ax.set_xlabel('x ', color='r', fontsize='14')
    ax.set_ylabel('y ', color='g', fontsize='14')
    ax.set_zlabel('z ', color='b', fontsize='14')
    ax.legend()
    plt.axis('off')
    plt.savefig(dir+'/{}.pdf'.format(data),pad_inches=0,bbox_inches='tight')
    plt.show()
# Out:
# /tmp/ipykernel_10314/650163624.py:12: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
